# %% [markdown]
# ## Instruções de uso
#
# Copiar todas as músicas para uma pasta chamada 'MusicasParaEditar'.
#
# Esta pasta deve estar localizada no Desktop.

# %%
import os
from pathlib import Path
import glob
import datetime
import eyed3

# %%
Raiz = str(Path.home()) + '/Desktop/MusicasParaEditar'
os.chdir(Raiz)

for FileName in glob.glob('*'):

    # Carregando arquivo
    AudioFile = eyed3.load(FileName)
    
    
    print(FileName)
    
    #AudioFile.tag.album = u"O Livro do Violão Brasileiro"
    #AudioFile.tag.artist = u"Nelson Faria"
    #AudioFile.tag.save()
    
    print(AudioFile.tag.album,
          AudioFile.tag.artist,
          AudioFile.tag.title)
# Out:
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# 418-M - 33 - Bossa Nova - Variaá∆o 2 - exemplo 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 2 - exemplo 2
# 418-M - 03 - Samba - Variaá∆o 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 1
# 418-M - 69 - bai∆o variation 4.mp3
# O Livro do Violão Brasileiro Nelson Faria baião variation 4
# 418-M - 44 - Exemplo de acompanhamento - 'Antes tarde'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de acompanhamento - 'Antes tarde'
# 418-M - 26 - Samba - Variaá∆o 17.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 17
# 418-M - 11 - Samba - Variaá∆o 6.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 6
# 418-M - 36 - Bossa Nova - Variaá∆o 3 - exemplo 3 - 'Brigas nunca mais'.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 3 - exemplo 3 - 'Brigas nunca mais'
# 418-M - 09 - Samba - Variaá∆o 4 - exemplo 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 4 - exemplo 2
# 418-M - 42 - Bossa Nova - Variaá∆o 6 - 'Aquarela do Brasil'.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 6 - 'Aquarela do Brasil'
# 418-M - 74 - Exemplo de acompanhamento - 'Bai∆o por Acaso'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de acompanhamento - 'Baião por Acaso'
# 418-M - 38 - Bossa Nova - Variaá∆o 4 - exemplo 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 4 - exemplo 2
# 418-M - 50 - Choro - Variaá∆o 4.mp3
# O Livro do Violão Brasileiro Nelson Faria Choro - Variação 4
# 418-M - 16 - Samba - Variaá∆o 8 - exemplo 1 - 'Feminina'.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 8 - exemplo 1 - 'Feminina'
# 418-M - 04 - Samba - Variaá∆o 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 2
# 418-M - 78 - Clave tocando um padr∆o de bossa nova.mp3
# O Livro do Violão Brasileiro Nelson Faria Clave tocando um padrão de bossa nova
# 418-M - 14 - Samba - Variaá∆o 7 - exemplo 3 - 'Incompatibilidade de gànios'.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 7 - exemplo 3 - 'Incompatibilidade de gênios'
# 418-M - 46 - Choro - Padr∆o b†sico.mp3
# O Livro do Violão Brasileiro Nelson Faria Choro - Padrão básico
# 418-M - 61 - Frevo - Variaá∆o 5.mp3
# O Livro do Violão Brasileiro Nelson Faria Frevo - Variação 5
# 418-M - 08 - Samba - Variaá∆o 4 - exemplo 1 - 'Desesperar jamais'.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 4 - exemplo 1 - Desesperar jamais'
# 418-M - 55 - Frevo - Padr∆o b†sico.mp3
# O Livro do Violão Brasileiro Nelson Faria Frevo - Padrão básico
# 418-M - 29 - Exemplo de melodia acompanhada (viol∆o solo) - 'Tristeza'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de melodia acompanhada (violão solo) - 'Tristeza'
# 418-M - 58 - Frevo - Variaá∆o 3.mp3
# O Livro do Violão Brasileiro Nelson Faria Frevo - Variação 3
# 418-M - 47 - Choro - Variaá∆o 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Choro - Variação 1
# 418-M - 73 - Exemplo de m£sica - 'Bai∆o por acaso'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de música - 'Baião por acaso'
# 418-M - 32 - Bossa Nova - Variaá∆o 2 - exemplo 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 2 - exemplo 1
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# Lame tag CRC check failed
# 418-M - 71 - Bai∆o - Variaá∆o 6.mp3
# O Livro do Violão Brasileiro Nelson Faria Baião - Variação 6
# 418-M - 40 - Bossa Nova - Variaá∆o 4 - exemplo 4 - 'Esse seu olhar'.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação
mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 13
# 418-M - 70 - Bai∆o - Variaá∆o 5.mp3
# O Livro do Violão Brasileiro Nelson Faria Baião - Variação 5
# 418-M - 77 - Ganz† tocando um padr∆o de bossa nova.mp3
# O Livro do Violão Brasileiro Nelson Faria Ganzá tocando um padrão de bossa nova
# 418-M - 05 - Samba - Variaá∆o 3 - exemplo 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 3 - exemplo 1
# 418-M - 63 - Exemplo de acompanhamento - 'Ioiì'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de acompanhamento - 'Ioiô'
# 418-M - 65 - Bai∆o - Variaá∆o 1 - exemplo 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Baião - Variação 1 - exemplo 1
# 418-M - 12 - Samba - Variaá∆o 7 - exemplo 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 7 - exemplo 1
# 418-M - 67 - Bai∆o - Variaá∆o 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Baião - Variação 2
# 418-M - 43 - Exemplo de m£sica - 'Antes tarde'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de música - 'Antes tarde'
# 418-M - 41 - Bossa Nova - Variaá∆o 5 - 'ê com esse que eu vou'.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 5 - 'É com esse que eu vou'
# 418-M - 81 - Surdo tocando um padr∆o de frevo.mp3
# O Livro do Violão Brasileiro Nelson Faria Surdo tocando um padrão de frevo
# 418-M - 15 - Samba - Variaá∆o 7 - exemplo 4 - 'Coisa feita'.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 7 - exemplo 4 - 'Coisa feita'
# 418-M - 79 - Pandeiro tocando um padr∆o de choro.mp3
# O Livro do Violão Brasileiro Nelson Faria Pandeiro tocando um padrão de choro
# 418-M - 76 - Pandeiro tocando um padr∆o de samba.mp3
# O Livro do Violão Brasileiro Nelson Faria Pandeiro tocando um padrão de samba
# 418-M - 13 - Samba - Variaá∆o 7 - exemplo 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 7 - exemplo 2
# 418-M - 51 - Choro - Variaá∆o 5.mp3
# O Livro do Violão Brasileiro Nelson Faria Choro - Variação 5
# 418-M - 24 - Samba - Variaá∆o 15.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 15
# 418-M - 25 - Samba - Variaá∆o 16 - 'From the lonely afternoons'.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 16 - 'From the lonely afternoons'
# 418-M - 34 - Bossa Nova - Variaá∆o 3 - exemplo 1.mp3
# O Livro do Violão Brasileiro Nelson Faria Bossa Nova - Variação 3 - exemplo 1
# 418-M - 17 - Samba - Variaá∆o 8 - exemplo 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 8 - exemplo 2
# 418-M - 10 - Samba - Variaá∆o 5.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 5
# 418-M - 52 - Exemplo de m£sica - 'Influenciado'.mp3
# O Livro do Violão Brasileiro Nelson Faria Exemplo de música - 'Influenciado'
# 418-M - 60 - Frevo - Variaá∆o 4 - exemplo 2.mp3
# O Livro do Violão Brasileiro Nelson Faria Frevo - Variação 4 - exemplo 2
# 418-M - 48 - Choro - Variaá∆o 2 - 'Choros nß 1' de Heitor Villa-Lobos'.mp3
# O Livro do Violão Brasileiro Nelson Faria Choro - Variação 2 - 'Choros nº 1' de Heitor Villa-Lobos
# 418-M - 23 - Samba - Variaá∆o 14.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 14
# 418-M - 72 - Bai∆o - Variaá∆o 7.mp3
# O Livro do Violão Brasileiro Nelson Faria Baião - Variação 7
# 418-M - 21 - Samba - Variaá∆o 12 - 'Cravo e canela'.mp3
# O Livro do Violão Brasileiro Nelson Faria Samba - Variação 12 - 'Cravo e canela'
# 418-M - 68 - Bai∆o - Variaá∆o 3.mp3
# O Livro do Violão Brasileiro Nelson Faria Baião - Variação 3

# %%
Ano=str()
Mes=str()



# For loop iterando por todos os arquivos
for file in glob.glob('*'):
    
    # Obtendo a data em datetime
    data = datetime.datetime.fromtimestamp(os.path.getmtime(file), tz=None)
    
    # Criando as string Ano e Mes
    Ano = data.strftime("%Y")
    Mes = data.strftime("%m") + " - " + data.strftime("%b")
    
    # Verificando se já existe o diretorio e acessando
    AcessaPasta(Ano,Mes)
    
    # Movendo o arquivo
    os.replace(Raiz + "/" + file, os.getcwd() + "/" + file)
    
    os.chdir(Raiz)
